# %%
pip install kagglehub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nehaprabhavalkar/indian-food-101")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 6.79k/6.79k [00:00<00:00, 80.4kB/s]
# Extracting files...
# Path to dataset files: C:\Users\hp\.cache\kagglehub\datasets\nehaprabhavalkar\indian-food-101\versions\2

# %%
import pandas as pd
import os

csv_file = os.path.join(path, "indian_food.csv")

df = pd.read_csv(csv_file)

df.head()
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
#
#          diet  prep_time  cook_time flavor_profile   course        state  \
# 0  vegetarian         45         25          sweet  dessert  West Bengal
# 1  vegetarian         80         30          sweet  dessert    Rajasthan
# 2  vegetarian         15         60          sweet  dessert       Punjab
# 3  vegetarian         15         30          sweet  dessert    Rajasthan
# 4  vegetarian         15         40          sweet  dessert  West Bengal
#
#   region
# 0   East
# 1   West
# 2  North
# 3   West
# 4   East

# %%
df.head(25)
# Out:
#               name                                        ingredients  \
# 0       Balu shahi                    Maida flour, yogurt, oil, sugar
# 1           Boondi                            Gram flour, ghee, sugar
# 2   Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3           Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4      Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5           Imarti                          Sugar syrup, lentil flour
# 6           Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7       Kaju katli                     Cashews, ghee, cardamom, sugar
# 8         Kalakand                        Milk, cottage cheese, sugar
# 9            Kheer                    Milk, rice, sugar, dried fruits
# 10           Laddu                            Gram flour, ghee, sugar
# 11           Lassi                          Yogurt, milk, nuts, sugar
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    str
#  1   ingredients     255 non-null    str
#  2   diet            255 non-null    str
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    str
#  6   course          255 non-null    str
#  7   state           255 non-null    str
#  8   region          254 non-null    str
# dtypes: int64(2), str(7)
# memory usage: 41.7 KB

# %%
df.tail()
# Out:
#           name                                        ingredients        diet  \
# 250  Til Pitha            Glutinous rice, black sesame seeds, gur  vegetarian
# 251    Bebinca  Coconut milk, egg yolks, clarified butter, all...  vegetarian
# 252     Shufta  Cottage cheese, dry dates, dried rose petals, ...  vegetarian
# 253  Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...  vegetarian
# 254     Pinaca  Brown rice, fennel seeds, grated coconut, blac...  vegetarian
#
#      prep_time  cook_time flavor_profile   course            state      region
# 250          5         30          sweet  dessert            Assam  North East
# 251         20         60          sweet  dessert              Goa        West
# 252         -1         -1          sweet  dessert  Jammu & Kashmir       North
# 253         20         45          sweet  dessert   Madhya Pradesh     Central
# 254         -1         -1          sweet  dessert              Goa        West

# %%
df.tail(15)
# Out:
#                    name                                        ingredients  \
# 240           Konir Dom  Aloo, tomatoes, mustard oil, bay leaf, cinnamo...
# 241         Koldil Duck  Rice flour, mutton, banana, gram flour, olive ...
# 242          Masor Koni  Fish roe, pumpkin flowers, mustard oil, turmer...
# 243  Mishti Chholar Dal  Chana dal, fresh coconut, ginger, cinnamon, ra...
# 244             Pakhala        Curd, cooked rice, curry leaves, dry chilli
# 245          Pani Pitha  Tea leaves, white sesame seeds, dry coconut, s...
# 246              Payokh  Basmati rice, rose water, sugar, clarified but...
# 247   Prawn malai curry      Coconut milk, prawns, garlic, turmeric, sugar
# 248            Red Rice  Red pepper, red onion, butter, watercress, oli...
# 249              Shukto  Green beans, bitter gourd, ridge gourd, banana...
# 250           Til Pitha            Glutinous rice, black sesame seeds, gur
# ...

# %%
df.shape
# Out:
# (255, 9)

# %%
df.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='str')

# %%
df.describe()
# Out:
#         prep_time   cook_time
# count  255.000000  255.000000
# mean    31.105882   34.529412
# std     72.554409   48.265650
# min     -1.000000   -1.000000
# 25%     10.000000   20.000000
# 50%     10.000000   30.000000
# 75%     20.000000   40.000000
# max    500.000000  720.000000

# %%
df.describe(include='all')
# Out:
#               name              ingredients        diet   prep_time  \
# count          255                      255         255  255.000000
# unique         255                      252           2         NaN
# top     Balu shahi  Gram flour, ghee, sugar  vegetarian         NaN
# freq             1                        2         226         NaN
# mean           NaN                      NaN         NaN   31.105882
# std            NaN                      NaN         NaN   72.554409
# min            NaN                      NaN         NaN   -1.000000
# 25%            NaN                      NaN         NaN   10.000000
# 50%            NaN                      NaN         NaN   10.000000
# 75%            NaN                      NaN         NaN   20.000000
# max            NaN                      NaN         NaN  500.000000
#
#          cook_time flavor_profile       course    state region
# count   255.000000            255          255      255    254
# ...

# %%
df["cook_time"].mean()
# Out:
# np.float64(34.529411764705884)

# %%
df["cook_time"].max()
# Out:
# np.int64(720)

# %%
df["prep_time"].median()
# Out:
# np.float64(10.0)

# %%
df["diet"].mode()
# Out:
# 0    vegetarian
# Name: diet, dtype: str

# %%
df["region"].nunique()
# Out:
# 7

# %%
df["cook_time"].quantile(0.75)
# Out:
# np.float64(40.0)

# %%
df["prep_time"].skew()
# Out:
# np.float64(4.636300925063016)

# %%
df.groupby("diet")["prep_time"].mean()
# Out:
# diet
# non vegetarian    27.068966
# vegetarian        31.623894
# Name: prep_time, dtype: float64

# %%
df.groupby("flavor_profile")["cook_time"].median()
# Out:
# flavor_profile
# -1        20.0
# bitter    35.0
# sour      10.0
# spicy     30.0
# sweet     30.0
# Name: cook_time, dtype: float64

# %%
df.isna()
# Out:
#       name  ingredients   diet  prep_time  cook_time  flavor_profile  course  \
# 0    False        False  False      False      False           False   False
# 1    False        False  False      False      False           False   False
# 2    False        False  False      False      False           False   False
# 3    False        False  False      False      False           False   False
# 4    False        False  False      False      False           False   False
# ..     ...          ...    ...        ...        ...             ...     ...
# 250  False        False  False      False      False           False   False
# 251  False        False  False      False      False           False   False
# 252  False        False  False      False      False           False   False
# 253  False        False  False      False      False           False   False
# 254  False        False  False      False      False           False   False
#
#      state  region
# 0    False   False
# ...

# %%
df.isna().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#          name                                        ingredients        diet  \
# 110  Panjeeri  Whole wheat flour, musk melon seeds, poppy see...  vegetarian
#
#      prep_time  cook_time flavor_profile   course          state region
# 110         10         25          sweet  dessert  Uttar Pradesh    NaN

# %%
df.notna()
# Out:
#      name  ingredients  diet  prep_time  cook_time  flavor_profile  course  \
# 0    True         True  True       True       True            True    True
# 1    True         True  True       True       True            True    True
# 2    True         True  True       True       True            True    True
# 3    True         True  True       True       True            True    True
# 4    True         True  True       True       True            True    True
# ..    ...          ...   ...        ...        ...             ...     ...
# 250  True         True  True       True       True            True    True
# 251  True         True  True       True       True            True    True
# 252  True         True  True       True       True            True    True
# 253  True         True  True       True       True            True    True
# 254  True         True  True       True       True            True    True
#
#      state  region
# 0     True    True
# 1     True    True
# ...

# %%
df["diet"].str.strip()
# Out:
# 0      vegetarian
# 1      vegetarian
# 2      vegetarian
# 3      vegetarian
# 4      vegetarian
#           ...
# 250    vegetarian
# 251    vegetarian
# 252    vegetarian
# 253    vegetarian
# 254    vegetarian
# Name: diet, Length: 255, dtype: str

# %%
df["course"].str.startswith("Main")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 250    False
# 251    False
# 252    False
# 253    False
# 254    False
# Name: course, Length: 255, dtype: bool

# %%
df["region"].str.title()
# Out:
# 0            East
# 1            West
# 2           North
# 3            West
# 4            East
#           ...
# 250    North East
# 251          West
# 252         North
# 253       Central
# 254          West
# Name: region, Length: 255, dtype: str

# %%
df["name"].str.upper()
# Out:
# 0          BALU SHAHI
# 1              BOONDI
# 2      GAJAR KA HALWA
# 3              GHEVAR
# 4         GULAB JAMUN
#             ...
# 250         TIL PITHA
# 251           BEBINCA
# 252            SHUFTA
# 253         MAWA BATI
# 254            PINACA
# Name: name, Length: 255, dtype: str

# %%
df["state"].str.split(",")
# Out:
# 0          [West Bengal]
# 1            [Rajasthan]
# 2               [Punjab]
# 3            [Rajasthan]
# 4          [West Bengal]
#              ...
# 250              [Assam]
# 251                [Goa]
# 252    [Jammu & Kashmir]
# 253     [Madhya Pradesh]
# 254                [Goa]
# Name: state, Length: 255, dtype: object

# %%
df["diet"].str.isalpha()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 250    True
# 251    True
# 252    True
# 253    True
# 254    True
# Name: diet, Length: 255, dtype: bool

# %%
df["state"].str.slice(0, 5)
# Out:
# 0      West
# 1      Rajas
# 2      Punja
# 3      Rajas
# 4      West
#        ...
# 250    Assam
# 251      Goa
# 252    Jammu
# 253    Madhy
# 254      Goa
# Name: state, Length: 255, dtype: str

# %%
df["course"].str.repeat(2)
# Out:
# 0      dessertdessert
# 1      dessertdessert
# 2      dessertdessert
# 3      dessertdessert
# 4      dessertdessert
#             ...
# 250    dessertdessert
# 251    dessertdessert
# 252    dessertdessert
# 253    dessertdessert
# 254    dessertdessert
# Name: course, Length: 255, dtype: str

# %%
df[df["name"].str.startswith("A")].groupby("course")["prep_time"].mean()
# Out:
# course
# dessert         11.666667
# main course     10.625000
# snack          150.000000
# Name: prep_time, dtype: float64

# %%
df.sort_values("cook_time", ascending=False)
# Out:
#              name                                        ingredients  \
# 62      Shrikhand                     Curd, sugar, saffron, cardamom
# 27        Malapua         Yoghurt, refined flour, ghee, fennel seeds
# 75        Biryani  Chicken thighs, basmati rice, star anise, swee...
# 114   Pindi chana   Fennel, tea bags, tomato, kasuri methi, cinnamon
# 115  Rajma chaval  Red kidney beans, garam masala powder, ginger,...
# ..            ...                                                ...
# 242    Masor Koni  Fish roe, pumpkin flowers, mustard oil, turmer...
# 240     Konir Dom  Aloo, tomatoes, mustard oil, bay leaf, cinnamo...
# 248      Red Rice  Red pepper, red onion, butter, watercress, oli...
# 252        Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 254        Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# ...

# %%
df.groupby("state")[["prep_time","cook_time"]].agg(["mean","min","max"])
# Out:
#                   prep_time           cook_time
#                        mean min  max       mean min  max
# state
# -1                63.083333  -1  360  35.041667  -1   90
# Andhra Pradesh    61.000000   5  240  37.500000  15   75
# Assam              5.714286  -1   20  14.285714  -1   40
# Bihar             21.666667  10   45  66.666667  20  120
# Chhattisgarh      10.000000  10   10  60.000000  60   60
# Goa                9.666667  -1   20  33.000000  -1   60
# Gujarat           13.742857  -1   35  26.485714  -1   60
# Haryana           10.000000  10   10  60.000000  60   60
# Jammu & Kashmir    9.500000  -1   20  24.500000  -1   50
# Karnataka         60.833333   5  180  44.166667  20   60
# Kerala            71.750000  -1  495  29.250000  -1   60
# Madhya Pradesh    15.000000  10   20  42.500000  40   45
# Maharashtra       15.400000  -1   70  51.100000  -1  720
# Manipur          119.500000  -1  240  22.000000  -1   45
# ...
